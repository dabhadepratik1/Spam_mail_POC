# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/DSCT/NLP/Spam Mail Classifier
# Out:
# /content/drive/MyDrive/Colab Notebooks/DSCT/NLP/Spam Mail Classifier

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import nltk
import re
from gensim.parsing.preprocessing import remove_stopwords
import numpy as np
import pandas as pd
import joblib

# %%
nltk.download('stopwords')
lemmatizer=WordNetLemmatizer()
stop_words=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
cv=joblib.load("cv.pkl")
ML_Model=joblib.load("RFC_Model.pkl")

# %%
cv
# Out:
# TfidfVectorizer(max_features=5000)

# %%
ML_Model
# Out:
# RandomForestClassifier(max_depth=2)

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
def text_cleaner(text):
  # Remove allother char except a-z and A-Z
  sent=re.sub('[^a-zA-z]',' ',text)

  # convert into lower case
  sent=sent.lower()

  # Lemmatization
  sent=" ".join([lemmatizer.lemmatize(word) for word in str(sent).split()])

  # remove Stopwords
  sent=" ".join([word for word in str(sent).split() if (word not in stop_words)])

  return sent
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
# "Subject: tenaska iv july
# darren :
# please remove the price on the tenaska iv sale , deal 384258 , for july and enter the demand fee . the amount should be $ 3 , 902 , 687 . 50 .
# thanks ,
# megan"

#ham 
# its not spam spam mail

# %%
raw_mail="""Subject: tenaska iv july
darren :
please remove the price on the tenaska iv sale , deal 384258 , for july and enter the demand fee . the amount should be $ 3 , 902 , 687 . 50 .
thanks ,
megan"""

# %%
print("Before cleaning:- ",raw_mail)

cleaned_mail=text_cleaner(raw_mail)
print("after cleaning :- ",cleaned_news)
# Out:
# Before cleaning:-  Subject: tenaska iv july
# darren :
# please remove the price on the tenaska iv sale , deal 384258 , for july and enter the demand fee . the amount should be $ 3 , 902 , 687 . 50 .
# thanks ,
# megan
# after cleaning :-  subject tenaska iv july darren please remove price tenaska iv sale deal july enter demand fee amount thanks megan

# %%
X=cv.transform([cleaned_mail])
X
# Out:
# <1x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>

# %%
pred=ML_Model.predict(X)[0]

if(pred=="ham"):
  print("{} :- Mail is not spam".format(raw_mail))

else:
  print("{} :- Mail is spam".format(raw_mail))
# Out:
# Subject: tenaska iv july
# darren :
# please remove the price on the tenaska iv sale , deal 384258 , for july and enter the demand fee . the amount should be $ 3 , 902 , 687 . 50 .
# thanks ,
# megan :- Mail is not spam
